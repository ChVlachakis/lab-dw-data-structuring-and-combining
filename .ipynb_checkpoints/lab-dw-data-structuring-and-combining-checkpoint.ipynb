# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %%
# Concatenate the sales, and sales_2 vertically (along rows)
pd.concat([df_1, df_2], axis=0).reset_index(drop=True)

# %%
# If join='inner', only the overlapping columns are included in the result, and non-overlapping columns are exclude
pd.concat([df_1, df_2,], axis=0, join="inner")

# %%
# Merge the sales and revenue DataFrames on the 'Clumn_name' column (inner join)
# Only rows with a common value in the 'Date' column, present in both DataFrames, are included in the merged result.
pd.merge(df_1, df_2, on='Column_name')

# %%
# If you want to perform an outer join, where all rows from both DataFrames are included, you can use how='outer'
pd.merge(df_1, df_2, on='Column_name', how='outer')

# %%
# If you want to include all rows from the left DataFrame and only the matching rows from the right DataFrame, you can use `how='left'`.
pd.merge(df_1, df_2, on='Column_name', how='left')

# %%
# Similarly, if you want to include all rows from the right DataFrame and only the matching rows from the left DataFrame, you can use `how='right'`.
pd.merge(df_1, df_2, on='Column_name', how='right')

# %%
# join(): Combines DataFrames based on their indexes. It uses the index as the key to align the rows.
# to use join, we must set one "Column_name" as the index for all the tables to be joined.
df_1.set_index('Column_name', inplace=True)
df_2.set_index('Column_name', inplace=True)
# then
df_sales.join([df_1, df_2], how='inner or outer')

# %%
# PIVOT
df.pivot(index="Column_1", columns="Column_2", values="Column_3")

# when providing an aggregation function, place the values in a list:
pivot_df = df.pivot_table(index='Column_1', columns='Column_2', values=['Column_3'], aggfunc='sum')

# %%
# stack(): This method "stacks" the data, converting the columns into rows, and results in a multi-level index. It is useful when you have a DataFrame with multiple columns representing similar data, and you want to combine them into a single column.
# BUT FIRST: Create a multi-index DataFrame using set_index with the index columns of choice.
df_multiindex = df.set_index(['Column_1', 'Column_2'])
# then
stacked_data = df_multiindex.stack()

# %%
# The melt() function in pandas is used to transform a DataFrame from a wide format to a long format, which is often more suitable for certain data analysis tasks.
# For example: Melt the DataFrame, keeping 'country' and 'year' as identifier variables, and 'Population' and 'GDP' as value variables
melted_data = pd.melt(df, id_vars=['country', 'year'], value_vars=['Population', 'GDP'], var_name='Indicator', value_name='Value')

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# first I import the cleaned data file from the first link, based on the work I did in the previous lab.
import pandas as pd
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
insurance_company_1_df = pd.read_csv("insurance_company_cleaned.csv")
insurance_company_1_df
# Out:
#      customer       state   gender             education  \
# 0     RB50392  Washington  Unknown                Master
# 1     QZ44356     Arizona        F              Bachelor
# 2     AI49188      Nevada        F              Bachelor
# 3     WW63253  California        M              Bachelor
# 4     GA49547  Washington        M  High School or Below
# ...       ...         ...      ...                   ...
# 1066  TM65736      Oregon        M                Master
# 1067  VJ51327  California        F  High School or Below
# 1068  GS98873     Arizona        F              Bachelor
# 1069  CW49887  California        F                Master
# 1070  MY31220  California        F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                  588174.235      0.0                1000.0
# 1                  697953.590      0.0                  94.0
# 2                 1288743.170  48767.0                 108.0
# ...

# %%
import pandas as pd
url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
insurance_company_2_df = pd.read_csv(url2)
insurance_company_2_df
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
import pandas as pd
url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"
insurance_company_3_df = pd.read_csv(url3)
insurance_company_3_df
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# first checking if the three tables have the same columns

# %%
insurance_company_1_df.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
# transforming the columns of tables 2 and 3 to the same format.

# %%
insurance_company_2_df.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
insurance_company_2_df.columns = insurance_company_2_df.columns.str.replace(" ", "_", regex=False).str.strip().str.lower()

# %%
insurance_company_2_df = insurance_company_2_df.rename(columns={"st": "state"})
insurance_company_2_df.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
insurance_company_3_df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
insurance_company_3_df.columns = insurance_company_3_df.columns.str.replace(" ", "_", regex=False).str.strip().str.lower()
insurance_company_3_df = insurance_company_3_df.rename(columns={"st": "state"})
insurance_company_3_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
# now checking if the contain the same columns

# %%
set(insurance_company_1_df.columns) == set(insurance_company_2_df.columns) == set(insurance_company_3_df.columns)
# Out:
# True

# %%
# that means that we can use the same cleaning techniques we used for the first dataframe.
# we will concatenate tables 2 and 3, and then apply the cleaning.

# %%
temporary_df = pd.concat([insurance_company_2_df, insurance_company_3_df], axis=0).reset_index(drop=True)
temporary_df
# Out:
#      customer       state gender education customer_lifetime_value  income  \
# 0     GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1     CW49887  California      F    Master              462680.11%   79487
# 2     MY31220  California      F   College              899704.02%   54230
# 3     UH35128      Oregon      F   College             2580706.30%   71210
# 4     WH52799     Arizona      F   College              380812.21%   94903
# ...       ...         ...    ...       ...                     ...     ...
# 8061  LA72316  California      M  Bachelor             23405.98798   71941
# 8062  PK87824  California      F   College             3096.511217   21604
# 8063  TD14365  California      M  Bachelor             8163.890428       0
# 8064  UP19263  California      M   College             7524.442436   21941
# 8065  Y167826  California      M   College             2611.836866       0
#
# ...

# %%
temporary_df["gender"].unique()
# Out:
# array(['F', 'M', nan, 'female', 'Male'], dtype=object)

# %%
temporary_df["gender"] = temporary_df["gender"].map({"F" : "F", "M" : "M", "Male" : "M", "female" : "F", "Femal" : "F"})
temporary_df.gender.unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
temporary_df["state"].unique()
# Out:
# array(['Arizona', 'California', 'Oregon', 'Nevada', 'Washington', 'AZ'],
#       dtype=object)

# %%
temporary_df["state"] = temporary_df["state"].map({"AZ" : "Arizona", "WA" : "Washington", "Cali" : "California", "Washington" : "Washington", "Arizona" : "Arizona", "Nevada" : "Nevada", "California" : "California", "Oregon" : "Oregon"})
temporary_df.state.unique()
# Out:
# array(['Arizona', 'California', 'Oregon', 'Nevada', 'Washington'],
#       dtype=object)

# %%
temporary_df["education"].unique()
# Out:
# array(['Bachelor', 'Master', 'College', 'Doctor', 'Bachelors',
#        'High School or Below'], dtype=object)

# %%
temporary_df["education"] = temporary_df["education"].map({"Master" : "Master", "Bachelor" : "Bachelor", "Bachelors" : "Bachelor", "High School or Below" : "High School or Below", "College" : "College", "Doctor" : "Doctor"})
temporary_df.education.unique()
# Out:
# array(['Bachelor', 'Master', 'College', 'Doctor', 'High School or Below'],
#       dtype=object)

# %%
# In Customer Lifetime Value, delete the % character

temporary_df["customer_lifetime_value"] = temporary_df["customer_lifetime_value"].astype("string").str.strip("%")
temporary_df
# Out:
#      customer       state gender education customer_lifetime_value  income  \
# 0     GS98873     Arizona      F  Bachelor               323912.47   16061
# 1     CW49887  California      F    Master               462680.11   79487
# 2     MY31220  California      F   College               899704.02   54230
# 3     UH35128      Oregon      F   College              2580706.30   71210
# 4     WH52799     Arizona      F   College               380812.21   94903
# ...       ...         ...    ...       ...                     ...     ...
# 8061  LA72316  California      M  Bachelor             23405.98798   71941
# 8062  PK87824  California      F   College             3096.511217   21604
# 8063  TD14365  California      M  Bachelor             8163.890428       0
# 8064  UP19263  California      M   College             7524.442436   21941
# 8065  Y167826  California      M   College             2611.836866       0
#
# ...

# %%
# In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"
temporary_df["vehicle_class"].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Luxury Car', 'Sports Car',
#        'Luxury SUV'], dtype=object)

# %%
temporary_df["vehicle_class"] = temporary_df["vehicle_class"].map({"Four-Door Car" : "Four-Door Car", "Two-Door Car" : "Two-Door Car", "SUV" : "SUV", "Luxury SUV" : "Luxury", "Sports Car" : "Luxury", "Luxury Car" : "Luxury"})
temporary_df["vehicle_class"].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Luxury'], dtype=object)

# %%
# formatting data types to concatenate with the clean table:
temporary_df["gender"] = temporary_df["gender"].astype("string")
temporary_df["education"] = temporary_df["education"].astype("string")
temporary_df["policy_type"] = temporary_df["policy_type"].astype("string")
temporary_df["vehicle_class"] = temporary_df["vehicle_class"].astype("string")
temporary_df["customer_lifetime_value"] = temporary_df["customer_lifetime_value"].astype("Float64")
temporary_df["number_of_open_complaints"] = temporary_df["number_of_open_complaints"].astype("string")
temporary_df["number_of_open_complaints"] = temporary_df["number_of_open_complaints"].str.split("/").str[1]
temporary_df["number_of_open_complaints"] = temporary_df["number_of_open_complaints"].astype("Int64")
temporary_df.dtypes
# Out:
# customer                             object
# state                                object
# gender                       string[python]
# education                    string[python]
# customer_lifetime_value             Float64
# income                                int64
# monthly_premium_auto                  int64
# number_of_open_complaints             Int64
# total_claim_amount                  float64
# policy_type                  string[python]
# vehicle_class                string[python]
# dtype: object

# %%
temporary_df
# Out:
#      customer       state gender education  customer_lifetime_value  income  \
# 0     GS98873     Arizona      F  Bachelor                323912.47   16061
# 1     CW49887  California      F    Master                462680.11   79487
# 2     MY31220  California      F   College                899704.02   54230
# 3     UH35128      Oregon      F   College                2580706.3   71210
# 4     WH52799     Arizona      F   College                380812.21   94903
# ...       ...         ...    ...       ...                      ...     ...
# 8061  LA72316  California      M  Bachelor              23405.98798   71941
# 8062  PK87824  California      F   College              3096.511217   21604
# 8063  TD14365  California      M  Bachelor              8163.890428       0
# 8064  UP19263  California      M   College              7524.442436   21941
# 8065  Y167826  California      M   College              2611.836866       0
#
# ...

# %%
# dropping null values

# %%
temporary_df.isnull().sum()
# Out:
# customer                        0
# state                           0
# gender                          5
# education                       0
# customer_lifetime_value         4
# income                          0
# monthly_premium_auto            0
# number_of_open_complaints    7070
# total_claim_amount              0
# policy_type                     0
# vehicle_class                   0
# dtype: int64

# %%
# filling NaN gender with "Unknown"
temporary_df["gender"] = temporary_df["gender"].fillna("Unknown")
# customre lifetime value with the median of temporary_df (we could do it as well with the median of all 3 tables for more accurate results, but since the temporary tables has more than 8000 rows, and only 4 values are missing, we consifer this median accurate enough.
median__temp_clv = temporary_df["customer_lifetime_value"].median()
temporary_df["customer_lifetime_value"] = (temporary_df["customer_lifetime_value"].fillna(median__temp_clv))
temporary_df.isnull().sum()
# Out:
# customer                        0
# state                           0
# gender                          0
# education                       0
# customer_lifetime_value         0
# income                          0
# monthly_premium_auto            0
# number_of_open_complaints    7070
# total_claim_amount              0
# policy_type                     0
# vehicle_class                   0
# dtype: int64

# %%
# we consider most likely, that the reason that for 7070 customer IDs we have NaN values at open complaints, is because the actual value of them is 0.
temporary_df["number_of_open_complaints"] = (temporary_df["number_of_open_complaints"].fillna(0))
temporary_df.isnull().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# total_claim_amount           0
# policy_type                  0
# vehicle_class                0
# dtype: int64

# %%
# and now we concatenate
insurance_updated_df = pd.concat([insurance_company_1_df, temporary_df], axis=0).reset_index(drop=True)
insurance_updated_df
# Out:
#      customer       state   gender             education  \
# 0     RB50392  Washington  Unknown                Master
# 1     QZ44356     Arizona        F              Bachelor
# 2     AI49188      Nevada        F              Bachelor
# 3     WW63253  California        M              Bachelor
# 4     GA49547  Washington        M  High School or Below
# ...       ...         ...      ...                   ...
# 9132  LA72316  California        M              Bachelor
# 9133  PK87824  California        F               College
# 9134  TD14365  California        M              Bachelor
# 9135  UP19263  California        M               College
# 9136  Y167826  California        M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                  588174.235      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
# The rows and columns total indicate that everything has been merged coorectly.

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
url_marketing = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"
insurance_and_marketing_df = pd.read_csv(url_marketing)
insurance_and_marketing_df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
insurance_and_marketing_df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
insurance_and_marketing_df = insurance_and_marketing_df.drop(columns=["unnamed:_0"])
insurance_and_marketing_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
insurance_and_marketing_df.columns = insurance_and_marketing_df.columns.str.replace(" ", "_", regex=False).str.strip().str.lower()
insurance_and_marketing_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
# now that we cleaned and formatted the columns, let's check for null values and duplicates.
insurance_and_marketing_df.isnull().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# month                            0
# dtype: int64

# %%
# that's fantastic, Marketing does an excellent job in reporting data. 
# But before we give them a golden star, let's see if there are duplicates.

# %%
insurance_and_marketing_df.duplicated().sum()
# Out:
# np.int64(443)

# %%
# Check for duplicates in columns where duplicates could create an issue, like customer, the rest can have duplicates.
insurance_and_marketing_df.duplicated(subset=['customer']).sum()
# Out:
# np.int64(1776)

# %%
# if rows had empty values based on the check above, it would be essential to check which duplicates to drop, keeping those with the most values. 
# since no rows have NaN values, then we can simply perform a basic duplicates drop.

# %%
# now let's drop them
insurance_and_marketing_df = insurance_and_marketing_df.drop_duplicates(subset=['customer'])
insurance_and_marketing_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# the above means that all duplicated were 443, all in the customer column, and were repeated more than 4 times. After deleting the duplications, we end up with the 443 unique rows from those customers.

# %%
insurance_and_marketing_df
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
# first let's create a column for the reveue per customer.
# to calculate the total revenue per customer, I need to bring the monthly_premium_auto information from the 'insurance_updated_df'.
# we will do an inner merge, to discard the extra 3 rows that the marketing table has compared to the insurance one.

merged_df = insurance_and_marketing_df.merge(
    insurance_updated_df[["customer", "monthly_premium_auto"]],
    on="customer",
    how="inner"
)
merged_df.head(5)
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...     policy_type  \
# 0        2011-02-18         Employed      M   48029  ...  Corporate Auto
# 1        2011-01-18       Unemployed      F       0  ...   Personal Auto
# 2        2011-02-10         Employed      M   22139  ...   Personal Auto
# 3        2011-01-11         Employed      M   49078  ...  Corporate Auto
# 4        2011-01-17    Medical Leave      F   23675  ...   Personal Auto
#
# ...

# %%
merged_df.shape
# Out:
# (9137, 27)

# %%
merged_df["customer"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Now let's create the pivot table
# first we need to create a column for the revenue:
merged_df["revenue"] = merged_df["monthly_premium_auto_y"]*merged_df["month"]
merged_df.head(5)
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...        policy  \
# 0        2011-02-18         Employed      M   48029  ...  Corporate L3
# 1        2011-01-18       Unemployed      F       0  ...   Personal L3
# 2        2011-02-10         Employed      M   22139  ...   Personal L3
# 3        2011-01-11         Employed      M   49078  ...  Corporate L3
# 4        2011-01-17    Medical Leave      F   23675  ...   Personal L2
#
#   renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# ...

# %%
pivot_df = merged_df.pivot_table(index='sales_channel', values=['revenue'], aggfunc='sum')
pivot_df["revenue"] = pivot_df["revenue"].round(2)
pivot_df.head(5)
# Out:
#                 revenue
# sales_channel
# Agent          644583.0
# Branch         405342.0
# Call Center    259203.0
# Web            191681.0

# %%
# Agents bring the most revenue for the company, followed by Branch, Call Center, and Web last

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_2_df = merged_df.pivot_table(index='gender', columns="education", values=['customer_lifetime_value'], aggfunc='mean')
pivot_2_df
# Out:
#           customer_lifetime_value                            \
# education                Bachelor      College       Doctor
# gender
# F                     7984.910997  7762.271500  7203.971670
# M                     7694.927580  7997.183541  7570.988441
#
#
# education High School or Below       Master
# gender
# F                  8572.477147  8304.774639
# M                  7914.019470  7953.182676

# %%
# using the pivot table above, we can see that th total lifetime value for females is bigger than for males, 
# with results varying across education level, but not at an extent that we se significant differences.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# first we need to bring in the merged_df table the values for 
customer_service_df = merged_df.merge(
    insurance_updated_df[["customer", "number_of_open_complaints", "policy_type"]],
    on="customer",
    how="inner"
)
customer_service_df.head(5)
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ... sales_channel  \
# 0        2011-02-18         Employed      M   48029  ...         Agent
# 1        2011-01-18       Unemployed      F       0  ...   Call Center
# 2        2011-02-10         Employed      M   22139  ...   Call Center
# 3        2011-01-11         Employed      M   49078  ...        Branch
# 4        2011-01-17    Medical Leave      F   23675  ...        Branch
#
#   total_claim_amount  vehicle_class  vehicle_size  vehicle_type  month  \
# ...

# %%
complaints = customer_service_df.groupby(["month", "policy_type_y"])["number_of_open_complaints_y"].sum()
complaints_long = complaints.reset_index()
print(complaints_long)
# Out:
#    month   policy_type_y  number_of_open_complaints_y
# 0      1  Corporate Auto                           73
# 1      1   Personal Auto                          363
# 2      1    Special Auto                           15
# 3      2  Corporate Auto                           78
# 4      2   Personal Auto                          249
# 5      2    Special Auto                           37
